# %%
#Detecting the content from the image, save the content into pdf format, convert text to speech.

# %%
from PIL import Image #PIL (Python Imaging Library)

# %%
import pytesseract as pst

# %%
pst.pytesseract.tesseract_cmd=r"C:\Program Files (x86)\Tesseract-OCR\tesseract.exe"

# %%
data=Image.open(r"D:\deep learning mad\testocr.png")

# %%
import cv2
mad=cv2.imread(r"D:\deep learning mad\testocr.png")
cv2.imshow("hhj",mad)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(data)
plt.axis("off")
# Out:
# (-0.5, 639.5, 479.5, -0.5)

# %%
text=pst.image_to_string(data)
print(text)
# Out:
# This is a lot of 12 point text to test the
# ocr code and see if it works on all types
# of file format.
#
# The quick brown dog jumped over the
# lazy fox. The quick brown dog jumped
# over the lazy fox. The quick brown dog
# jumped over the lazy fox. The quick
# brown dog jumped over the lazy fox.

# %%
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas

# %%
c = canvas.Canvas('output.pdf')
c.drawString(100, 700, text)
c.save()

# %%
import gtts
from gtts import gTTS

# %%
from playsound import playsound
from pydub import AudioSegment

# %%
image_text=gtts.gTTS(text)

# %%
tts = gTTS(text)
tts.save('output.mp3')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File ~\anaconda3\Lib\socket.py:962, in getaddrinfo(host, port, family, type, proto, flags)
#     961 addrlist = []
# ...

# %%
from IPython.display import Audio

# Play the audio within the Jupyter Notebook
audio = Audio(filename='output.mp3')
display(audio)
